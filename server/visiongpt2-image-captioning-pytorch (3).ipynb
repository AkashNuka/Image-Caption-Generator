# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from timm import create_model, list_models
from types import SimpleNamespace
from transformers import GPT2LMHeadModel, GPT2TokenizerFast, get_linear_schedule_with_warmup
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
from pathlib import Path
from sklearn.model_selection import train_test_split
from torch.cuda.amp import GradScaler, autocast
from tqdm.auto import tqdm
import gc
import json

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

# Define the nodes
nodes = [
    "User Interface\n(Frontend)",
    "API Gateway\n(Backend - FastAPI)",
    "Machine Learning Model\n(ViT + GPT-2)",
    "Generated Caption\n(Return to UI)"
]

# Define the edges (data flow)
edges = [
    ("User Interface\n(Frontend)", "API Gateway\n(Backend - FastAPI)"),
    ("API Gateway\n(Backend - FastAPI)", "Machine Learning Model\n(ViT + GPT-2)"),
    ("Machine Learning Model\n(ViT + GPT-2)", "API Gateway\n(Backend - FastAPI)"),
    ("API Gateway\n(Backend - FastAPI)", "Generated Caption\n(Return to UI)"),
    ("Generated Caption\n(Return to UI)", "User Interface\n(Frontend)")
]

# Add nodes and edges to the graph
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# Define positions for each node
pos = {
    "User Interface\n(Frontend)": (0, 1),
    "API Gateway\n(Backend - FastAPI)": (2, 1),
    "Machine Learning Model\n(ViT + GPT-2)": (4, 0),
    "Generated Caption\n(Return to UI)": (2, -1)
}

# Draw the graph
plt.figure(figsize=(10, 6))
nx.draw(
    G,
    pos,
    with_labels=True,
    node_size=3000,
    node_color="lightgreen",
    font_size=10,
    font_weight="bold",
    edge_color="gray",
    arrowsize=20
)

# Add title
plt.title("Simplified Data Flow for Image Captioning System", fontsize=14)

# Show the diagram
plt.tight_layout()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_14016\1365302994.py:54: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

def add_block(ax, text, x, y, width=2, height=1, color="lightblue"):
    """Add a labeled block to the diagram."""
    ax.add_patch(Rectangle((x, y), width, height, edgecolor="black", facecolor=color, lw=2))
    ax.text(x + width / 2, y + height / 2, text, ha="center", va="center", fontsize=10, wrap=True)

# Create the figure and axes
fig, ax = plt.subplots(figsize=(14, 10))

# Add blocks for the Vision-GPT2 architecture
# Left Encoder (ViT)
add_block(ax, "Input Image\n(Pixels)", -2, 7, width=2)
add_block(ax, "Patch Embedding", 0, 6)
add_block(ax, "Positional Embedding", 0, 4.5)
add_block(ax, "12x ViT Encoder\n(Self Attention)", 0, 3, height=2)
add_block(ax, "MLP", 0, 1.5)
add_block(ax, "Norm", 0, 0)

# Right Decoder (GPT-2)
add_block(ax, "Token Embedding", 6, 6)
add_block(ax, "Positional Embedding", 6, 4.5)
add_block(ax, "Causal Multihead\nSelf Attention", 6, 3, height=2)
add_block(ax, "Norm", 6, 1.5)
add_block(ax, "MLP", 6, 0)
add_block(ax, "12x GPT Decoder", 6, -1, height=2)
add_block(ax, "LM Head\n(Logits)", 6, -3)

# Add arrows for data flow
# Encoder arrows
ax.arrow(-1, 7.5, 1, -1, head_width=0.2, head_length=0.3, fc="black", ec="black")  # Input Image -> Patch Embedding
ax.arrow(1, 6.5, 0, -1, head_width=0.2, head_length=0.3, fc="black", ec="black")  # Patch Embedding -> Positional Embedding
ax.arrow(1, 5, 0, -1, head_width=0.2, head_length=0.3, fc="black", ec="black")  # Positional Embedding -> ViT Encoder
ax.arrow(1, 3, 0, -1.5, head_width=0.2, head_length=0.3, fc="black", ec="black")  # ViT Encoder -> MLP
ax.arrow(1, 1.5, 0, -1.5, head_width=0.2, head_length=0.3, fc="black", ec="black")  # MLP -> Norm

# Decoder arrows
ax.arrow(7, 6.5, 0, -1, head_width=0.2, head_length=0.3, fc="black", ec="black")  # Token Embedding -> Positional Embedding
ax.arrow(7, 5, 0, -1, head_width=0.2, head_length=0.3, fc="black", ec="black")  # Positional Embedding -> GPT Decoder
ax.arrow(7, -1, 0, -1, head_width=0.2, head_length=0.3, fc="black", ec="black")  # GPT Decoder -> LM Head

# Cross-attention arrow (Encoder to Decoder)
ax.arrow(1.5, 3, 4, 0, head_width=0.2, head_length=0.3, fc="black", ec="black", linestyle="--")  # ViT -> Decoder Attention

# Output arrows
ax.arrow(7, -2.5, 1.5, 0, head_width=0.3, head_length=0.4, fc="black", ec="black")  # LM Head -> Output Caption
add_block(ax, "Generated Caption\n(Back to UI)", 9, -3, width=2, color="lightgreen")

# Label the arrows for clarity
ax.text(3.5, 3.3, "Cross-Attention", fontsize=10, rotation=0, color="blue")

# Adjust plot limits and hide axes
ax.set_xlim(-3, 12)
ax.set_ylim(-4, 9)
ax.axis("off")

# Title
plt.title("Vision-GPT2 Image Captioning Architecture", fontsize=14)

# Show the diagram
plt.tight_layout()
plt.show()

# %%
# %env TOKENIZERS_PARALLELISM = false
# Out:
# env: TOKENIZERS_PARALLELISM=false

# %%
tokenizer = GPT2TokenizerFast.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token
tokenizer.pad_token
# Out:
# c:\Users\akash\anaconda3\envs\capenv\Lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# '<|endoftext|>'

# %%
class Dataset:
    def __init__(self, df, tfms):
        self.df = df
        self.tfms = tfms
    def __len__(self):
        return len(self.df)
    def __getitem__(self,idx):
        sample = self.df.iloc[idx,:]
        image = sample['image']
        caption = sample['caption']
        image = Image.open(image).convert('RGB')
        image = np.array(image)
        augs = self.tfms(image=image)
        image = augs['image']
        caption = f"{caption}<|endoftext|>"
        input_ids = tokenizer(
            caption,
            truncation=True)['input_ids']
        labels = input_ids.copy()
        labels[:-1] = input_ids[1:]
        return image,input_ids,labels

# %%
def collate_fn(batch):
    image = [i[0] for i in batch]
    input_ids = [i[1] for i in batch]
    labels = [i[2] for i in batch]
    image = torch.stack(image,dim=0)
    input_ids = tokenizer.pad(
        {'input_ids':input_ids},
        padding='longest',
        return_attention_mask=False,
        return_tensors='pt'
    )['input_ids']
    labels = tokenizer.pad(
        {'input_ids':labels},
        padding='longest',
        return_attention_mask=False,
        return_tensors='pt'
    )['input_ids']
    mask = (input_ids!=tokenizer.pad_token_id).long()
    labels[mask==0]=-100
    return image, input_ids, labels

# %%
class GPT2Attention(nn.Module):
    def __init__(self,config):
        super().__init__()
        self.embed_dim = config.embed_dim
        self.n_heads = config.num_heads
        assert self.embed_dim % self.n_heads == 0, 'embedding dimension by be divisible by number of heads'
        self.head_size = self.embed_dim // self.n_heads
        self.seq_len = config.seq_len
        
        self.c_attn = nn.Linear(self.embed_dim, self.head_size * self.n_heads * 3,bias=True)
        self.scale = self.head_size ** -0.5
        
        self.register_buffer('mask',torch.tril(torch.ones(1,1,self.seq_len,self.seq_len)))
        
        self.c_proj = nn.Linear(self.embed_dim, self.embed_dim, bias=True)
        
        self.attn_dropout = nn.Dropout(config.attention_dropout)
        self.resid_dropout = nn.Dropout(config.residual_dropout)
        
        
    def forward(self, x):
        b,t,c = x.shape
        # q,k,v shape individually: batch_size x seq_len x embed_dim
        # we know that qk_t = q x k_t, where q=bxtxhead_dim, k_t=bxhead_timxt
        q,k,v = self.c_attn(x).chunk(3,dim=-1)
        q = q.view(b,t,self.n_heads,self.head_size).permute(0,2,1,3) # batch x n_heads x seq_len x head_dim
        k = k.view(b,t,self.n_heads,self.head_size).permute(0,2,1,3)
        v = v.view(b,t,self.n_heads,self.head_size).permute(0,2,1,3)
        
        qk_t = (q@k.transpose(-2,-1)) * self.scale
        qk_t = qk_t.masked_fill(self.mask[:,:,:t,:t]==0,float('-inf'))
        qk_t = F.softmax(qk_t,dim=-1)
        weights = self.attn_dropout(qk_t)
        
        attention = weights @ v # batch x n_heads x t x head_size
        attention = attention.permute(0,2,1,3).contiguous().view(b,t,c) # batch x t x embed_dim
        
        out = self.c_proj(attention)
        out = self.resid_dropout(out)
        
        return out

# %%
class GPT2CrossAttention(nn.Module):
    def __init__(self,config):
        super().__init__()
        self.embed_dim = config.embed_dim
        self.n_heads = config.num_heads
        assert self.embed_dim % self.n_heads == 0, 'embedding dimension by be divisible by number of heads'
        self.head_size = self.embed_dim // self.n_heads
        self.seq_len = config.seq_len
        
        self.q = nn.Linear(self.embed_dim,self.embed_dim)
        self.k = nn.Linear(self.embed_dim,self.embed_dim)
        self.v = nn.Linear(self.embed_dim,self.embed_dim)
        self.scale = self.head_size ** -0.5
        
        self.c_proj = nn.Linear(self.embed_dim, self.embed_dim, bias=True)
        
        self.attn_dropout = nn.Dropout(config.attention_dropout)
        self.resid_dropout = nn.Dropout(config.residual_dropout)
        
        self.apply(self._init_weights)
        
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        
        
    def forward(self, q,k,v):
        b,t,c = q.shape
        
        q = self.q(q)
        k = self.k(k)
        v = self.v(v)
        
        q = q.view(b,q.size(1),self.n_heads,self.head_size).permute(0,2,1,3) # batch x n_heads x seq_len x head_dim
        k = k.view(b,k.size(1),self.n_heads,self.head_size).permute(0,2,1,3)
        v = v.view(b,v.size(1),self.n_heads,self.head_size).permute(0,2,1,3)
        
        qk_t = (q@k.transpose(-2,-1)) * self.scale
        qk_t = F.softmax(qk_t,dim=-1)
        weights = self.attn_dropout(qk_t)
        
        attention = weights @ v # batch x n_heads x t x head_size
        attention = attention.permute(0,2,1,3).contiguous().view(b,t,c) # batch x t x embed_dim
        
        out = self.c_proj(attention)
        out = self.resid_dropout(out)
        
        return out

# %%
class GPT2MLP(nn.Module):
    def __init__(self,config):
        super().__init__()
        self.embed_dim = config.embed_dim
        self.mlp_ratio = config.mlp_ratio
        self.mlp_dropout = config.mlp_dropout
        
        self.c_fc = nn.Linear(self.embed_dim,self.embed_dim*self.mlp_ratio)
        self.c_proj = nn.Linear(self.embed_dim*self.mlp_ratio,self.embed_dim)
        self.act = nn.GELU()
        self.dropout = nn.Dropout(self.mlp_dropout)
        
    def forward(self,x):
        x = self.c_fc(x)
        x = self.act(x)
        x = self.c_proj(x)
        x = self.dropout(x)
        return x

# %%
class GPT2Block(nn.Module):
    def __init__(self,config):
        super().__init__()
        self.embed_dim = config.embed_dim
        self.ln_1 = nn.LayerNorm(self.embed_dim)
        self.attn = GPT2Attention(config)
        self.ln_2 = nn.LayerNorm(self.embed_dim)
        self.mlp = GPT2MLP(config)
        self.ln_3 = nn.LayerNorm(self.embed_dim)
        self.cross_attn = GPT2CrossAttention(config)
        
    def forward(self,x,enc_out):
        x = x+self.attn(self.ln_1(x))
        x = x+self.cross_attn(self.ln_2(x),enc_out,enc_out)
        x = x+self.mlp(self.ln_3(x))
        return x

# %%
class VisionGPT2Model(nn.Module):
    def __init__(self,config):
        super().__init__()
        
        self.config = config
        
        vit = create_model('vit_base_patch16_224',pretrained=True,num_classes=0)
        self.patch_embed = vit.patch_embed
        num_patches = self.patch_embed.num_patches
        
        self.cls_token = vit.cls_token
        embed_len = num_patches + vit.num_prefix_tokens
        self.pos_embed = vit.pos_embed
        self.pos_drop = nn.Dropout(p=0.)
        
        self.blocks = nn.ModuleList([vit.blocks[i] for i in range(config.depth)])
        
        self.transformer = nn.ModuleDict(dict(
            wte = nn.Embedding(config.vocab_size,config.embed_dim),
            wpe = nn.Embedding(config.seq_len,config.embed_dim),
            drop = nn.Dropout(config.emb_dropout),
            h = nn.ModuleList([GPT2Block(config) for _ in range(config.depth)]),
            ln_f = nn.LayerNorm(config.embed_dim)
        ))
        self.lm_head = nn.Linear(config.embed_dim,config.vocab_size,bias=False)
        self.transformer.wte.weight = self.lm_head.weight
        
    def _pos_embed(self,x):
        pos_embed = self.pos_embed
        x = torch.cat((self.cls_token.expand(x.shape[0], -1, -1), x), dim=1)
        x = x + pos_embed
        return self.pos_drop(x)
    
    def pretrained_layers_trainable(self,trainable=False):
        layers = [
            self.cls_token, self.patch_embed, self.pos_embed, self.blocks,
            self.transformer.wte, self.transformer.wpe,
            self.transformer.ln_f, self.lm_head
        ]
        gpt_layers = [[
            self.transformer.h[i].ln_1,self.transformer.h[i].ln_2,
            self.transformer.h[i].attn,self.transformer.h[i].mlp
        ] for i in range(self.config.depth)]
        for l in gpt_layers:
            layers.extend(l)
        
        for layer in layers:
            if not isinstance(layer,nn.Parameter):
                for p in layer.parameters():
                    p.requires_grad = trainable
            else:
                layer.requires_grad = trainable
                
        total_frozen_params = sum([p.numel() for p in self.parameters() if not p.requires_grad])
        print(f'{total_frozen_params=}')
        
    def unfreeze_gpt_layers(self,):
        gpt_layers = [[
            self.transformer.h[i].ln_1,self.transformer.h[i].ln_2,
            self.transformer.h[i].attn,self.transformer.h[i].mlp
        ] for i in range(self.config.depth)]
        flatten = []
        for l in gpt_layers:
            flatten.extend(l)
            
        for layer in flatten:
            if not isinstance(layer,nn.Parameter):
                for p in layer.parameters():
                    p.requires_grad = True
            else:
                layer.requires_grad = True
        
    @classmethod    
    def from_pretrained(self,config):
        model = VisionGPT2Model(config)
        sd = model.state_dict()
        keys = sd.keys()
        ignore_matches = ['blocks.','cross_attn.','ln_3','cls_token','pos_embed','patch_embed.','.attn.mask']
        vit_keys = [key for key in keys if any(match in key for match in ignore_matches)]
        gpt_keys = [key for key in keys if key not in vit_keys]
        
        gpt2_small = GPT2LMHeadModel.from_pretrained('gpt2')
        sd_hf = gpt2_small.state_dict()
        hf_keys = sd_hf.keys()
        hf_keys = [k for k in hf_keys if not k.endswith('.attn.masked_bias')]
        hf_keys = [k for k in hf_keys if not k.endswith('.attn.bias')]
        transposed = ['attn.c_attn.weight', 'attn.c_proj.weight', 'mlp.c_fc.weight', 'mlp.c_proj.weight']
        
        for k in hf_keys:
            if any(match in k for match in ignore_matches):
                continue
            if any(k.endswith(w) for w in transposed):
                assert sd_hf[k].shape[::-1] == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k].t())
            else:
                assert sd_hf[k].shape == sd[k].shape
                with torch.no_grad():
                    sd[k].copy_(sd_hf[k])
            
        model.load_state_dict(sd)
        
        return model
    
    def forward(self,image,input_ids,labels=None):
        
        image = self.patch_embed(image)
        image = self._pos_embed(image)
        
        token_embeddings = self.transformer.wte(input_ids) # batch x seq_len
        pos_embs = torch.arange(0,input_ids.size(1)).to(input_ids.device)
        positional_embeddings = self.transformer.wpe(pos_embs)
        input_ids = self.transformer.drop(token_embeddings+positional_embeddings)
        
        for i in range(self.config.depth):
            image = self.blocks[i](image)
            input_ids = self.transformer.h[i](input_ids, image)
        
        input_ids = self.transformer.ln_f(input_ids)
        
        if labels is not None:
            lm_logits = self.lm_head(input_ids)
            loss = F.cross_entropy(lm_logits.view(-1, lm_logits.shape[-1]), labels.view(-1))
            return loss
        
        lm_logits = self.lm_head(input_ids[:,[-1],:])
        return lm_logits
    
    def generate(self,image,sequence,max_tokens=50,temperature=1.0,deterministic=False):
        for _ in range(max_tokens):
            out = self(image,sequence)
            out = out[:,-1,:] / temperature
            probs = F.softmax(out,dim=-1)
            if deterministic:
                next_token = torch.argmax(probs,dim=-1,keepdim=True)
            else:
                next_token = torch.multinomial(probs,num_samples=1)
            sequence = torch.cat([sequence,next_token],dim=1)
            if next_token.item() == tokenizer.eos_token_id:
                break
            
        return sequence.cpu().flatten()

# %%
class Trainer:
    def __init__(self,model_config,train_config, dls):
        
        self.train_config = train_config
        self.model_config = model_config
        self.device = self.train_config.device
        
        self.model = VisionGPT2Model.from_pretrained(model_config).to(self.device)
        self.model.pretrained_layers_trainable(trainable=False)
        
        print(f'trainable parameters: {sum([p.numel() for p in self.model.parameters() if p.requires_grad])}')
        
        self.tokenizer = GPT2TokenizerFast.from_pretrained('gpt2')
        self.tokenizer.pad_token = self.tokenizer.eos_token
        
        self.scaler = GradScaler()
        
        self.train_dl, self.val_dl = dls
        
        total_steps = len(self.train_dl)
        
        self.optim = torch.optim.Adam(self.model.parameters(), lr=self.train_config.lr / 25.)
        self.sched = torch.optim.lr_scheduler.OneCycleLR(
            self.optim,
            max_lr=self.train_config.lr,
            epochs=self.train_config.epochs,
            steps_per_epoch=total_steps
        )
        
#         self.sched = get_linear_schedule_with_warmup(self.optim,num_warmup_steps=0,num_training_steps=total_steps)
        
        self.metrics = pd.DataFrame()
        self.metrics[['train_loss','train_perplexity','val_loss','val_perplexity']] = None
        
        self.gen_tfms = A.Compose([
            A.Resize(224,224),
            A.Normalize(mean=[0.5,0.5,0.5],std=[0.5,0.5,0.5],always_apply=True),
            ToTensorV2()
        ])
            
        
    def save_model(self,):
        self.train_config.model_path.mkdir(exist_ok=True)
        sd = self.model.state_dict()
        torch.save(sd,self.train_config.model_path/'captioner.pt')
        
        
    def load_best_model(self,):
        sd = torch.load(self.train_config.model_path/'captioner.pt')
        self.model.load_state_dict(sd)
    
    
    def train_one_epoch(self,epoch):
        
        prog = tqdm(self.train_dl,total=len(self.train_dl))
        
        running_loss = 0.
        
        for image, input_ids, labels in prog:
            
            with autocast():
                image = image.to(self.device)
                input_ids = input_ids.to(self.device)
                labels = labels.to(self.device)
                
                loss = self.model(image,input_ids,labels)
                
                self.scaler.scale(loss).backward()
                self.scaler.step(self.optim)
                self.scaler.update()
                self.sched.step()
                self.optim.zero_grad(set_to_none=True)
                
                running_loss += loss.item()
                
                prog.set_description(f'train loss: {loss.item():.3f}')
                
            del image, input_ids, labels, loss
            
        train_loss = running_loss / len(self.train_dl)
        train_pxp = np.exp(train_loss)
        
        self.metrics.loc[epoch,['train_loss','train_perplexity']] = (train_loss,train_pxp)
        
        
    @torch.no_grad()
    def valid_one_epoch(self,epoch):
        
        prog = tqdm(self.val_dl,total=len(self.val_dl))
        
        running_loss = 0.
        
        for image, input_ids, labels in prog:
            
            with autocast():
                image = image.to(self.device)
                input_ids = input_ids.to(self.device)
                labels = labels.to(self.device)
                
                loss = self.model(image,input_ids,labels)
                running_loss += loss.item()
                
                prog.set_description(f'valid loss: {loss.item():.3f}')
                
            del image, input_ids, labels, loss
            
        val_loss = running_loss / len(self.val_dl)
        val_pxp = np.exp(val_loss)
        
        self.metrics.loc[epoch,['val_loss','val_perplexity']] = (val_loss,val_pxp)
        
        return val_pxp
        
        
    def clean(self):
        gc.collect()
        torch.cuda.empty_cache()
       
    
    def fit(self,):
        
        best_pxp = 1e9
        best_epoch = -1
        prog = tqdm(range(self.train_config.epochs))
        
        for epoch in prog:
            
            if epoch == self.train_config.freeze_epochs_gpt:
                self.model.unfreeze_gpt_layers()
                print('unfreezing GPT2 entirely...')
                
            if epoch == self.train_config.freeze_epochs_all:
                self.model.pretrained_layers_trainable(trainable=True)
            
            self.model.train()
            prog.set_description('training')
            self.train_one_epoch(epoch)
            self.clean()
            
            self.model.eval()
            prog.set_description('validating')
            pxp = self.valid_one_epoch(epoch)
            self.clean()
            
            print(self.metrics.tail(1))
            
            if pxp < best_pxp:
                best_pxp = pxp
                best_epoch = epoch
                print('saving best model...')
                self.save_model()
                
        return {
            'best_perplexity': best_pxp,
            'best_epoch': best_epoch
        }
           
        
    @torch.no_grad()
    def generate_caption(self,image,max_tokens=50,temperature=1.0,deterministic=False):
        
        self.model.eval()
        
        image = Image.open(image).convert('RGB')
        image = np.array(image)
        image = self.gen_tfms(image=image)['image']
        image = image.unsqueeze(0).to(self.device)
        sequence = torch.ones(1,1).to(device=self.device).long() * self.tokenizer.bos_token_id
        
        caption = self.model.generate(
            image,
            sequence,
            max_tokens=max_tokens,
            temperature=temperature,
            deterministic=deterministic
        )
        caption = self.tokenizer.decode(caption.numpy(),skip_special_tokens=True)
        
        return caption

# %%
model_config = SimpleNamespace(
    vocab_size = 50_257,
    embed_dim = 768,
    num_heads = 12,
    seq_len = 1024,
    depth = 12,
    attention_dropout = 0.1,
    residual_dropout = 0.1,
    mlp_ratio = 4,
    mlp_dropout = 0.1,
    emb_dropout = 0.1,
)
train_config = SimpleNamespace(
    epochs = 5,
    freeze_epochs_gpt = 1,
    freeze_epochs_all = 2,
    lr = 1e-4,
    device = 'cuda',
    model_path = Path('captioner'),
    batch_size = 32
)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = VisionGPT2Model(model_config).to(device)

# Load the model state_dict
model.load_state_dict(torch.load(r'C:\Users\akash\Downloads\project-bolt-sb1-htfstm\project\captioner .pt', map_location=device))

# Set the model to evaluation mode
model.eval()

print("Model loaded successfully")
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_22132\1650106245.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(r'C:\Users\akash\Downloads\project-bolt-sb1-htfstm\project\captioner .pt', map_location=device))
# Model loaded successfully

# %%
print(model)

# Print the model's named parameters
for name, param in model.named_parameters():
    print(f"Parameter name: {name}, shape: {param.shape}")
# Out:
# VisionGPT2Model(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (blocks): ModuleList(
#     (0-11): 12 x Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (q_norm): Identity()
#         (k_norm): Identity()
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Linear(in_features=768, out_features=2304, bias=True)
#           (c_proj): Linear(in_features=768, out_features=768, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#           (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#           (act): GELU(approximate='none')
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_3): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (cross_attn): GPT2CrossAttention(
#           (q): Linear(in_features=768, out_features=768, bias=True)
#           (k): Linear(in_features=768, out_features=768, bias=True)
#           (v): Linear(in_features=768, out_features=768, bias=True)
#           (c_proj): Linear(in_features=768, out_features=768, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )
# Parameter name: cls_token, shape: torch.Size([1, 1, 768])
# Parameter name: pos_embed, shape: torch.Size([1, 197, 768])
# Parameter name: patch_embed.proj.weight, shape: torch.Size([768, 3, 16, 16])
# Parameter name: patch_embed.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.0.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.0.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.0.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.0.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.0.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.0.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.0.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.0.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.0.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.0.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.0.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.0.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.1.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.1.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.1.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.1.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.1.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.1.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.1.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.1.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.1.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.1.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.1.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.1.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.2.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.2.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.2.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.2.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.2.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.2.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.2.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.2.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.2.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.2.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.2.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.2.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.3.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.3.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.3.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.3.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.3.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.3.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.3.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.3.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.3.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.3.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.3.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.3.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.4.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.4.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.4.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.4.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.4.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.4.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.4.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.4.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.4.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.4.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.4.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.4.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.5.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.5.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.5.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.5.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.5.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.5.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.5.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.5.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.5.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.5.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.5.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.5.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.6.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.6.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.6.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.6.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.6.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.6.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.6.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.6.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.6.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.6.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.6.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.6.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.7.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.7.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.7.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.7.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.7.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.7.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.7.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.7.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.7.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.7.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.7.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.7.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.8.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.8.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.8.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.8.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.8.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.8.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.8.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.8.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.8.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.8.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.8.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.8.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.9.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.9.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.9.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.9.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.9.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.9.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.9.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.9.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.9.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.9.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.9.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.9.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.10.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.10.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.10.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.10.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.10.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.10.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.10.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.10.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.10.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.10.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.10.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.10.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: blocks.11.norm1.weight, shape: torch.Size([768])
# Parameter name: blocks.11.norm1.bias, shape: torch.Size([768])
# Parameter name: blocks.11.attn.qkv.weight, shape: torch.Size([2304, 768])
# Parameter name: blocks.11.attn.qkv.bias, shape: torch.Size([2304])
# Parameter name: blocks.11.attn.proj.weight, shape: torch.Size([768, 768])
# Parameter name: blocks.11.attn.proj.bias, shape: torch.Size([768])
# Parameter name: blocks.11.norm2.weight, shape: torch.Size([768])
# Parameter name: blocks.11.norm2.bias, shape: torch.Size([768])
# Parameter name: blocks.11.mlp.fc1.weight, shape: torch.Size([3072, 768])
# Parameter name: blocks.11.mlp.fc1.bias, shape: torch.Size([3072])
# Parameter name: blocks.11.mlp.fc2.weight, shape: torch.Size([768, 3072])
# Parameter name: blocks.11.mlp.fc2.bias, shape: torch.Size([768])
# Parameter name: transformer.wte.weight, shape: torch.Size([50257, 768])
# Parameter name: transformer.wpe.weight, shape: torch.Size([1024, 768])
# Parameter name: transformer.h.0.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.0.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.0.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.0.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.0.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.0.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.0.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.0.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.0.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.0.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.0.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.0.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.0.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.0.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.0.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.1.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.1.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.1.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.1.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.1.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.1.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.1.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.1.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.1.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.1.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.1.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.1.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.1.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.1.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.2.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.2.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.2.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.2.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.2.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.2.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.2.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.2.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.2.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.2.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.2.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.2.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.2.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.2.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.3.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.3.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.3.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.3.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.3.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.3.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.3.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.3.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.3.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.3.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.3.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.3.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.3.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.3.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.4.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.4.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.4.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.4.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.4.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.4.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.4.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.4.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.4.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.4.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.4.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.4.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.4.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.4.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.5.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.5.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.5.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.5.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.5.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.5.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.5.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.5.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.5.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.5.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.5.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.5.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.5.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.5.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.6.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.6.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.6.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.6.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.6.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.6.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.6.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.6.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.6.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.6.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.6.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.6.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.6.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.6.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.7.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.7.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.7.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.7.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.7.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.7.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.7.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.7.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.7.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.7.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.7.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.7.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.7.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.7.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.8.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.8.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.8.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.8.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.8.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.8.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.8.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.8.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.8.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.8.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.8.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.8.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.8.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.8.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.9.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.9.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.9.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.9.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.9.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.9.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.9.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.9.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.9.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.9.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.9.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.9.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.9.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.9.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.10.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.10.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.10.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.10.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.10.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.10.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.10.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.10.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.10.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.10.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.10.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.10.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.10.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.10.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.ln_1.weight, shape: torch.Size([768])
# Parameter name: transformer.h.11.ln_1.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.attn.c_attn.weight, shape: torch.Size([2304, 768])
# Parameter name: transformer.h.11.attn.c_attn.bias, shape: torch.Size([2304])
# Parameter name: transformer.h.11.attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.11.attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.ln_2.weight, shape: torch.Size([768])
# Parameter name: transformer.h.11.ln_2.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.mlp.c_fc.weight, shape: torch.Size([3072, 768])
# Parameter name: transformer.h.11.mlp.c_fc.bias, shape: torch.Size([3072])
# Parameter name: transformer.h.11.mlp.c_proj.weight, shape: torch.Size([768, 3072])
# Parameter name: transformer.h.11.mlp.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.ln_3.weight, shape: torch.Size([768])
# Parameter name: transformer.h.11.ln_3.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.cross_attn.q.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.11.cross_attn.q.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.cross_attn.k.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.11.cross_attn.k.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.cross_attn.v.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.11.cross_attn.v.bias, shape: torch.Size([768])
# Parameter name: transformer.h.11.cross_attn.c_proj.weight, shape: torch.Size([768, 768])
# Parameter name: transformer.h.11.cross_attn.c_proj.bias, shape: torch.Size([768])
# Parameter name: transformer.ln_f.weight, shape: torch.Size([768])
# Parameter name: transformer.ln_f.bias, shape: torch.Size([768])
